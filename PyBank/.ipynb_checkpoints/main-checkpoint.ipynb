# %%
"""
In this activity, you are tasked with creating a Python script for analyzing the financial records of your company. You will be provided with a financial dataset in this file: budget_data.csv. This dataset is composed of two columns, Date and Profit/Losses. (Thankfully, your company has rather lax standards for accounting, so the records are simple.)
Your task is to create a Python script that analyzes the records to calculate each of the following:


The total number of months included in the dataset.


The net total amount of Profit/Losses over the entire period.


The average of the changes in Profit/Losses over the entire period.


The greatest increase in profits (date and amount) over the entire period.


The greatest decrease in losses (date and amount) over the entire period.


Your resulting analysis should look similar to the following:

Financial Analysis
----------------------------
Total Months: 86
Total: $38382578
Average  Change: $-2315.12
Greatest Increase in Profits: Feb-2012 ($1926159)
Greatest Decrease in Profits: Sep-2013 ($-2196167)
"""
# Import the pathlib and csv library
from pathlib import Path
import csv

# %%
# Set the file path to read budget_data.csv
csvpath = Path('budget_data.csv')

# %%
# Initialize Profit and Loss Table
pnl_tab = [] 

# Initialize Profit and Lost Dict Object to be added to the list
pnl = {}

# Initialize metrics variables
total_months = 0;
total = 0
avg_sum = 0
avg_sum_counter = 0;
avg_change = 0
max_change = 0
max_change_str = "";
min_change = 0
min_change_str = ""

# Open the input path as a file object
with open(csvpath, 'r') as csvfile:
    
    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delimiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile, delimiter=',')
    
    # Go to the next row from the start of the file
    # (which is often the first row/header) and iterate line_num by 1
    header = next(csvreader)
    line_num += 1
    
    #Print the header
    # print(f"{header} <----- HEADER")
    
    for row in csvreader:
        pnl = {}
        pnl['date'] = row[0]
        pnl['profitandloss'] = row[1]
        
        pnl_tab.append(pnl)
  
    # Loop through the profit and lost table
    for i in range(len(pnl_tab)-1):
        obj = {}
        nextobj = {}
        
        obj = pnl_tab[i]
        nextobj = pnl_tab[i+1]
        
        nextobj['change'] = int(nextobj['profitandloss']) - int(obj['profitandloss'])

    
    # Calculate Metrics
    total_months = len(pnl_tab)
    for i in range(len(pnl_tab)):
        obj = {}
        obj = pnl_tab[i]
        total += int(obj['profitandloss'])
        
        #Calculate Total Average Sum
        if 'change' in obj.keys():
            avg_sum_counter += 1
            avg_sum += obj['change']
            
            #Calculate Max Change
            current_max = int(obj['change'])
            if current_max > max_change:
                max_change = int(obj['change'])
                max_change_str = f"Greatest Increase in Profits: {obj['date']} (${obj['change']})"
                
            #Calculate Min Change
            current_min = int(obj['change'])
            if current_min < min_change:
                min_change = int(obj['change'])
                min_change_str = f"Greatest Decrease in Profits: {obj['date']} (${obj['change']})"

#Calculate Average Change
avg_chg = round( avg_sum / avg_sum_counter, 2)

#Print Metrics
print("Financial Analysis")
print("-------------------------")
print(f"Total Months: {total_months}")
print(f"Total: ${total}")
print(f"Average Change: ${avg_chg}")
print(f"{max_change_str}")
print(f"{min_change_str}")
# Out:
# Financial Analysis
# -------------------------
# Total Months: 86
# Total: $38382578
# Average Change: $-2315.12
# Greatest Increase in Profits: Feb-2012 ($1926159)
# Greatest Decrease in Profits: Sep-2013 ($-2196167)
